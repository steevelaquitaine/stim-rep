# %% [markdown]
# # Stimulus representation
#
# author: steeve.laquitaine@epfl.ch
# date: 21.02.1984
#
# ## Results
#
# ### 1. All cortical layers represent the stimulus
# ### 2. Exc. and Inh units differ
#
# a. by response pattern
# b. by stimulus response pattern
#
# ### 1. Exc. units
#
# a. response patterns cluster by layer [embedding)[DONE]
# b. represents stimulus similarly across layers (embedding, decoding)
# c. output units (L5 exc.) are same as cortical input units (L4)?
#
# Story: Stimulus rep. by exc. units is transf. across layer from L4 to L5, improving stimulus discrimination.
#
#
# ## Method
# ### Task
#
# * task parameters (see bbp_workflow config):
#     * start delay: 1000 ms
#     * stimulus delay: 1500 ms
#     * 360 stimuli x 50 repeated trials for characterizing the tuning curves
#     * interstimulus interval: 200 ms
#
# ### Dataset
#
# * data:
#     1. 36 simulation files
#     2. bbp_workflow config script spikesorting_stim_rotations.py indicates 36 files with orientations for file 1: 0 to 9, file 2: 10 to 19 etc...
#     3. png files confirm point 2): /gpfs/bbp.cscs.ch/project/proj83/scratch/home/isbister/post_physiology_2023/sim_data/campaigns/spikesorting_stimulus_tests/4_spikesorting_stimulus_test_neuropixels_8-1-24/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/35
#     5. Thus: Each simulation file is organized as: simulation file duration (101500 ms) = start delay of 1500 ms then 10 repeats of (orientation for 9800 ms followed by 200 ms of ISI)
#
# ### Dim. reduction
#
# * the time offset should be larger than the specified receptive field of the model (1)
#
# ### Notes:
#
# * CEBRA hybrid can't be run in multi-dataset mode (can't train over layers).
#
# # DONE
#
# * installing cebra
#
# # TODO
#
# * plot cebra embedding by layer
#
# ## References
#
# (1) https://cebra.ai/docs/usage.html

# %% [markdown]
# ### Setup
#
# 1. activate spikeinterf..

# %%
# SETUP PACKAGES 
# %load_ext autoreload
# %autoreload 2
import os
import numpy as np
from matplotlib import pyplot as plt
import matplotlib
import spikeinterface as si
import numpy as np
from collections import Counter
import pandas as pd
import random
import warnings
import pickle
from sklearn.preprocessing import LabelEncoder
import yaml

# dimensionality reduction
from sklearn.decomposition import PCA 
from cebra import CEBRA
import cebra

warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=UserWarning) 

# GET STIMULUS CONF
PROJ_PATH = "/gpfs/bbp.cscs.ch/project/proj85/home/laquitai/preprint_2023"
os.chdir(PROJ_PATH)
from src.nodes.utils import get_config

data_conf, _ = get_config("silico_neuropixels", "stimulus").values()
GT_SORTING_PATH = data_conf["sorting"]["simulation"]["ground_truth"]["output"]
RECORDING_PATH = data_conf["probe_wiring"]["output"]


# GET STIM-REP CONF
PROJ_PATH = "/gpfs/bbp.cscs.ch/project/proj85/home/laquitai/stim-rep"
os.chdir(PROJ_PATH)

with open(
    f"conf/silico_npx/stimulus/dataset.yml",
    "r",
    encoding="utf-8",
) as data_conf:
    data_conf = yaml.safe_load(data_conf)

# MODELS
CEBRA_MODEL_MTLYR_TRIAL_PATH = data_conf['models']['cebra']['models']['multilayer_trialwise']
CEBRA_MODEL_MTLYR_UNIT_PATH = data_conf['models']['cebra']['models']['multilayer_unitwise']

# EMBEDDINGS
CEBRA_EMBED_MTLYR_TRIAL_PATH = data_conf['models']['cebra']['embed']['multilayer_trialwise']
CEBRA_EMBED_MTLYR_UNIT_PATH = data_conf['models']['cebra']['embed']['multilayer_unitwise']

# TASK DESIGN PARAMETERS
N_SIMS = 36 # number of simulation files

# FIGURE SETTINGS
plt.rcParams['figure.figsize'] = (2,1)
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 6
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams['axes.linewidth'] = 0.5
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['xtick.major.width'] = 0.3
plt.rcParams['xtick.minor.size'] = 0.1
plt.rcParams['xtick.major.size'] = 1.5
plt.rcParams['ytick.major.size'] = 1.5
plt.rcParams['ytick.major.width'] = 0.3
legend_cfg = {"frameon": False, "handletextpad": 0.1}
savefig_cfg = {"transparent":True, "dpi":300}
# Out:
# 2024-05-07 18:47:11,038 - root - utils.py - get_config - INFO - Reading experiment config.
# 2024-05-07 18:47:11,090 - root - utils.py - get_config - INFO - Reading experiment config. - done

# %% [markdown]
# ### Define custom function

# %%
def plot_manifold_dims_1_2(manifold: dict, params, ax, axis_lim):

    # downsample manifold for speed
    # and memory efficiency
    DOWNSAMPLE = 10

    # color the stimulus orientations
    cmap = params["orientations"][::DOWNSAMPLE]

    # plot neural manifold
    scat = ax.scatter(
        manifold["manifold"][::DOWNSAMPLE, 0],
        manifold["manifold"][::DOWNSAMPLE, 1],
        c=cmap,
        edgecolors="w",
        linewidths=0.2,
        rasterized=True,  # memory efficiency
    )

    # add legend
    ax.set_xlim(axis_lim)
    ax.set_ylim(axis_lim)
    ax.set_xticklabels([-0.5, 0, 0.5, 1])
    ax.set_yticklabels([-0.5, 0, 0.5, 1])
    ax.set_xticks([-0.5, 0, 0.5, 1])
    ax.set_yticks([-0.5, 0, 0.5, 1])
    # cbar = plt.colorbar(scat, ticks=[0, 90, 180, 270, 359], fraction=0.026, pad=0.04)
    # cbar.ax.set_ylabel("Stimulus orientations (deg)", rotation=270, labelpad=7)
    # cbar.ax.set_yticklabels([0, 90, 180, 270, 359])

    # legend
    ax.set_xlabel("Neural latent 1")
    ax.set_ylabel("Neural latent 2")
    ax.spines[["top", "right"]].set_visible(False)
    ax.set_box_aspect((1))
    return ax


def get_stimulus_intervals_ms(epoch_labels, epoch_ms):

    # find stimulus epoch starts and ends
    epoch_end_ms = np.cumsum(epoch_ms)
    epoch_start_ms = np.hstack([0, epoch_end_ms])[:-1]
    df = pd.DataFrame(data=epoch_end_ms)
    df.columns = ["end"]
    df.insert(0, "start", epoch_start_ms)
    df.index = epoch_labels

    # get stimulus intervals
    return [tuple(df.iloc[ix]) for ix in range(len(df)) if df.index[ix] == "stimulus"]


def get_stimulus_labels():
    start = np.arange(0, 360, 10)
    end = np.arange(10, 370, 10)

    stimulus_labels = []
    for ix in range(36):
        stimulus_labels.append(np.repeat(np.arange(start[ix], end[ix], 1), 50))
    return np.array(stimulus_labels).flatten()


def get_task_parameters(
    start_delay=500,
    n_orientations=10,
    n_repeats=50,
    stimulus_duration=200,
    n_simulations=36,
):
    # get epoch timings
    epoch_ms = n_simulations * (
        [start_delay] + n_orientations * n_repeats * [stimulus_duration]
    )
    # get epoch labels
    epoch_labels = n_simulations * (
        ["delay"] + n_orientations * n_repeats * ["stimulus"]
    )

    return {"epoch_labels": epoch_labels, "epoch_ms": epoch_ms}


def get_evoked_responses(spike_trains_ms: np.array, stim_intervals_ms: np.array):
    """_summary_

    Args:
        spike_trains_ms (np.array): _description_
        stim_intervals_ms (np.array): array of tuples (start, end)

    Returns:
        _type_: _description_
    """
    # Use numpy's digitize function to find the bin indices for each value
    bins = [interval[1] for interval in stim_intervals_ms]

    # Return the indices of the bins to which each value in spike_trains_ms belongs.
    bin_indices = np.digitize(spike_trains_ms, bins=bins)

    # Use Counter to count occurrences of bin indices
    interval_counter = Counter(bin_indices)

    # find active stimulus epochs
    active_bin_spike_count = [items[1] for items in list(interval_counter.items())]
    active_bin_ix = [items[0] for items in list(interval_counter.items())]

    # cast unit responses by stimulus epoch in an array
    unit_responses = np.zeros(len(bins))
    unit_responses[active_bin_ix] = active_bin_spike_count
    return unit_responses


def convert_spike_trains_to_ms(spike_trains: np.array, sfreq: int):
    """_summary_

    Args:
        spike_trains (np.array): _description_
        sfreq (int): _description_

    Returns:
        _type_: _description_
    """
    sample_ms = 1 / (sfreq / 1000)
    spike_trains_ms = spike_trains * sample_ms
    return spike_trains_ms


def compute_response_by_stim_matrix(unit_ids, SortingTrueKS3, stimulus_intervals_ms):
    """_summary_

    Args:
        SortingTrueKS3 (_type_): _description_
        stimulus_intervals_ms (_type_): _description_

    Returns:
        _type_: _description_
    """
    SFREQ = SortingTrueKS3.get_sampling_frequency()

    # takes 18 secs
    responses = []
    for unit_id in unit_ids:
        spike_trains = SortingTrueKS3.get_unit_spike_train(unit_id)
        spike_trains_ms = convert_spike_trains_to_ms(spike_trains, SFREQ)
        responses.append(get_evoked_responses(spike_trains_ms, stimulus_intervals_ms))
    return np.array(responses)


def plot_manifold_from_pca(responses: np.ndarray, params: dict, ax, axis_lim):
    """PLot manifold

    Args:
      responses (np.ndarray): neurons x stimulus

    Returns:
        (dict)
    """
    # fit pca to neural responses
    pca = PCA(n_components=params["dims"])  # parametrize pca
    manifold = pca.fit_transform(responses.T)  # apply pca
    manifold = manifold / np.max(np.abs(manifold))  # normalise the values

    # setup plot parameters
    DOWNSAMPLE = 10

    # setup plot
    plt.set_cmap("hsv")  # circular cmap

    # 3D projection
    ax.view_init(20, 45, 0)  # elevation, azimuth, roll

    # color the stimulus orientations
    cmap = params["orientations"][::DOWNSAMPLE]

    # plot neural manifold
    scat = ax.scatter(
        manifold[::DOWNSAMPLE, 0],
        manifold[::DOWNSAMPLE, 1],
        manifold[::DOWNSAMPLE, 2],
        c=cmap,
        edgecolors="w",
        linewidths=0.2,
        s=2,
        rasterized=True,  # memory efficiency
    )

    # add legend
    ax.set_xlim(axis_lim)
    ax.set_ylim(axis_lim)
    ax.set_zlim(axis_lim)
    cbar = plt.colorbar(scat, ticks=[0, 90, 180, 270, 359], fraction=0.026, pad=0.04)
    cbar.ax.set_ylabel("Stimulus orientations (deg)", rotation=270, labelpad=7)
    cbar.ax.set_yticklabels([0, 90, 180, 270, 359])
    ax.set_xlabel("Neural latent 1")
    ax.set_ylabel("Neural latent 2")
    ax.set_zlabel("Neural latent 3")
    ax.set_xticks([-0.5, 0, 0.5, 1])
    ax.set_yticks([-0.5, 0, 0.5, 1])
    ax.set_zticks([-0.5, 0, 0.5, 1])
    ax.set_xticklabels(
        [-0.5, 0, 0.5, 1], verticalalignment="baseline", horizontalalignment="right"
    )
    ax.set_yticklabels(
        [-0.5, 0, 0.5, 1], verticalalignment="baseline", horizontalalignment="right"
    )
    ax.set_zticklabels(
        [-0.5, 0, 0.5, 1], verticalalignment="baseline", horizontalalignment="right"
    )
    ax.tick_params(axis="x", which="major", pad=-3)
    ax.tick_params(axis="y", which="major", pad=-3)
    ax.tick_params(axis="z", which="major", pad=-3)
    ax.set_xlabel("Neural latent 1", labelpad=-10)
    ax.set_ylabel("Neural latent 2", labelpad=-10)
    ax.set_zlabel("Neural latent 3", labelpad=-5)
    ax.spines[["top", "right"]].set_visible(False)
    ax.xaxis.pane.fill = False
    ax.yaxis.pane.fill = False
    ax.zaxis.pane.fill = False
    ax.set_box_aspect((1, 1, 1))
    print("manifold axis max:", max(manifold.max(axis=1)))
    print("manifold axis min:", min(manifold.min(axis=1)))
    return {"manifold": manifold, "pca_model": pca, "ax": ax}

# %% [markdown]
# ### (22s) Load dataset

# %%
# sorting
SortingTrue = si.load_extractor(GT_SORTING_PATH)

# unit layers
unit_layers = SortingTrue.get_property("layer")
print("# of unit layers:", len(np.unique(unit_layers)))
print("unique unit layers:", np.unique(unit_layers))

# recording
Recording = si.load_extractor(RECORDING_PATH)
print("# of units:", len(SortingTrue.unit_ids))

# get task epoch infos
task = get_task_parameters(
    start_delay=500,
    n_orientations=10,
    n_repeats=50,
    stimulus_duration=200,
    n_simulations=36,
)

# STIMULUS  ***********

# get stimulus labels
stimulus_labels = get_stimulus_labels()
print("# of stimulus trials:", len(stimulus_labels))
print("# of stimulus orientations:", len(np.unique(stimulus_labels)))

# get stimulus orientation labels
stimulus_intervals_ms = get_stimulus_intervals_ms(
    task["epoch_labels"], task["epoch_ms"]
)

print("orientations:", stimulus_intervals_ms)

# NEURAL RESPONSE ***********

# compute unit x stimulus response matrix
responses = compute_response_by_stim_matrix(
    SortingTrue.unit_ids, SortingTrue, stimulus_intervals_ms
)

# UNIT LABELS ***********

syn = SortingTrue.get_property("synapse_class")
enc = LabelEncoder()
unit_labels = [
    np.array([enc.fit_transform(syn[(unit_layers == "2") | (unit_layers == "3")])])
    .astype(np.float32)
    .T,
    np.array([enc.fit_transform(syn[unit_layers == "4"])]).astype(np.float32).T,
    np.array([enc.fit_transform(syn[unit_layers == "5"])]).astype(np.float32).T,
    np.array([enc.fit_transform(syn[unit_layers == "6"])]).astype(np.float32).T,
]
# Out:
# # of unit layers: 6
# unique unit layers: ['1' '2' '3' '4' '5' '6']
# # of units: 1836
# # of stimulus trials: 18000
# # of stimulus orientations: 360
# ...

# %% [markdown]
# ### PCA
#
# * 50 micron-radius surrounding the central axis of the column (1836 units): what a neuropixels probe should capture.

# %% [markdown]
# ##### Parametrize

# %%
# set parameters
params = {"orientations": stimulus_labels}
params_pca = {
    "dims": 3,  # dimensions
    "orientations": params["orientations"],  # stimulus orientations
}

# %% [markdown]
# #### Trial-wise manifold
#
# * each point is a trial

# %%
# takes 20 secs
FIG_SIZE = (2.8, 2.8)

# plot
fig = plt.figure(figsize=FIG_SIZE)

# 3D manifold
ax = fig.add_subplot(2, 1, 1, projection="3d")
pca_out_t = plot_manifold_from_pca(responses, params_pca, ax, axis_lim=[-0.6, 1.1])

# 2D manifold
ax = fig.add_subplot(2, 1, 2)
ax = plot_manifold_dims_1_2(pca_out_t, params, ax, axis_lim=[-0.6, 1.1])
# Out:
# manifold axis max: 1.0
# manifold axis min: -0.5180597494284631

# %% [markdown]
# #### Neuron-wise
#
# * each point is a neuron.
# * no unit clusters.

# %%
# setup plot parameters
DOWNSAMPLE = 10
FIG_SIZE = (8, 2.8)
# cmap = params["orientations"][::DOWNSAMPLE] # color the stimulus orientations

# get manifold
pca = PCA(n_components=params_pca["dims"])  # parametrize pca
manifold_n = pca.fit_transform(responses)
manifold_n = manifold_n / np.max(np.abs(manifold_n))  # normalise the values

# init plot
plt.set_cmap("hsv")  # circular cmap
fig = plt.figure(figsize=FIG_SIZE)
ax = fig.add_subplot(1, 4, 1, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll

# plot
scat = ax.scatter(
    manifold_n[:, 0],
    manifold_n[:, 1],
    manifold_n[:, 2],
    # c=cmap,
    edgecolors="w",
    linewidths=0.2,
    s=6,
    rasterized=True,  # memory efficiency
)

# plot
ax = fig.add_subplot(1, 4, 2)
scat = ax.scatter(
    manifold_n[:, 0],
    manifold_n[:, 1],
    edgecolors="w",
    linewidths=0.2,
    s=6,
    rasterized=True,
)

# plot
ax = fig.add_subplot(1, 4, 3)
scat = ax.scatter(
    manifold_n[:, 1],
    manifold_n[:, 2],
    edgecolors="w",
    linewidths=0.2,
    s=6,
    rasterized=True,
)

# plot
ax = fig.add_subplot(1, 4, 4)
scat = ax.scatter(
    manifold_n[:, 0],
    manifold_n[:, 2],
    edgecolors="w",
    linewidths=0.2,
    s=6,
    rasterized=True,
)

# %% [markdown]
# ### Layer-wise (CEBRA)
#
# * Does the orientation manifold change across layers?
# * How does information capacity change through layers? From the inputs to the ouput layers?
# * Why does it change? Class manifold radii, dimensionality, centroid correlation change?
#
# **Method**:
# * <u>PCA limitation</u>: A PCA embedding could be trained over all the responses, then response could be projected to the embedding by layer. But PCA requires X to have the same number of columns while layers have different number of unit columns.
# * We used CEBRA. Multiple datasets must share the same dimensionality across samples, but can have differing feature dimensions (e.g. number of neurons).
# * We train CEBRA-hybrid from different cortical layers and compute linear consistencies between them, using the parameters of Chang et al., bioRxiv, 2024
#     * multi dataset training does not yet support Hybrid=True, so we used cebra--behavior.
#     * multi-dataset training finds the same latent space (three latents axes) across the five layers.
#     * we drop layer 1 (only 6 neurons all inhibitory).

# %% [markdown]
# #### Trial-wise
#
# **Null hypothesis:** Cortical layers do not represent the stimulus orientation.
#
# **Hypothesis 1:** Cortical layers all represent stimulus orientations in the same way.
# * Prediction: the topology of the stimulus embeddings should differ between layers.
# * Result: all layers' embeddings were ring manifolds with very strong consistency that continuously represented stimulus orientations.
# * Conclusion: the response patterns induced by the stimulus orientations are very similar between layers.

# %%
MAX_ITER = 12000

# format dataset
names = ["L2/3", "L4", "L5", "L6"]

# layer-wise responses
datas = [
    responses[(unit_layers == "2") | (unit_layers == "3"), :].T,
    responses[unit_layers == "4", :].T,
    responses[unit_layers == "5", :].T,
    responses[unit_layers == "6", :].T,
]

# trial labels (auxiliary variable)
labels = [
    np.array([stimulus_labels]).astype(np.float32).T,
    np.array([stimulus_labels]).astype(np.float32).T,
    np.array([stimulus_labels]).astype(np.float32).T,
    np.array([stimulus_labels]).astype(np.float32).T,
]

cebra_multilayer_trialwise_embed = dict()

# cebra - behavior model
cebra_multilayer_trialwise = CEBRA(
    model_architecture="offset5-model",  # CEBRA model with a 5 sample receptive field and output normalization.
    batch_size=1200,
    learning_rate=1e-4,
    temperature=1,
    output_dimension=3,
    max_iterations=MAX_ITER,  # 8000,
    distance="cosine",
    conditional="time_delta",
    device="cuda_if_available",
    verbose=True,
    time_offsets=10,
)

# (3m) train and save ******************************************
# train
np.random.seed(0)

cebra_multilayer_trialwise.fit(datas, labels)
cebra_multilayer_trialwise.save(CEBRA_MODEL_MTLYR_TRIAL_PATH)

# get each layer's embedding
for i, (name, X) in enumerate(zip(names, datas)):
    cebra_multilayer_trialwise_embed[name] = cebra_multilayer_trialwise.transform(
        X, session_id=i
    )

# save
with open(CEBRA_EMBED_MTLYR_TRIAL_PATH, "wb") as f:
    pickle.dump(cebra_multilayer_trialwise_embed, f)


# plot
SIZE = 1

# init plot
plt.set_cmap("hsv")  # circular cmap
fig = plt.figure(figsize=(15, 4))

# plot
ax = fig.add_subplot(1, 4, 1, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    cebra_multilayer_trialwise_embed["L2/3"][:, 0],
    cebra_multilayer_trialwise_embed["L2/3"][:, 1],
    cebra_multilayer_trialwise_embed["L2/3"][:, 2],
    c=stimulus_labels,
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot
ax = fig.add_subplot(1, 4, 2, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    cebra_multilayer_trialwise_embed["L4"][:, 0],
    cebra_multilayer_trialwise_embed["L4"][:, 1],
    cebra_multilayer_trialwise_embed["L4"][:, 2],
    c=stimulus_labels,
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot ******************************************
ax = fig.add_subplot(1, 4, 3, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    cebra_multilayer_trialwise_embed["L5"][:, 0],
    cebra_multilayer_trialwise_embed["L5"][:, 1],
    cebra_multilayer_trialwise_embed["L5"][:, 2],
    c=stimulus_labels,
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot
ax = fig.add_subplot(1, 4, 4, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    cebra_multilayer_trialwise_embed["L6"][:, 0],
    cebra_multilayer_trialwise_embed["L6"][:, 1],
    cebra_multilayer_trialwise_embed["L6"][:, 2],
    c=stimulus_labels,
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,
)

# %% [markdown]
# #### Unit-wise

# %% [markdown]
# ##### parametrize

# %%
# format dataset
names = ["L2/3", "L4", "L5", "L6"]

datas = [
    responses[(unit_layers == "2") | (unit_layers == "3"), :],
    responses[unit_layers == "4", :],
    responses[unit_layers == "5", :],
    responses[unit_layers == "6", :],
]

# %%
# cebra-behavior model
cebra_multilayer_unitwise_model = CEBRA(
    model_architecture="offset5-model",  # CEBRA model with a 5 sample receptive field and output normalization.
    batch_size=1200,  # 1200,  # 512, # must be 512
    learning_rate=1e-4,
    temperature=1,
    output_dimension=3,
    max_iterations=MAX_ITER,  # 8000,
    distance="cosine",
    conditional="time_delta",
    device="cuda_if_available",
    verbose=True,
    time_offsets=10,
)

# %% [markdown]
# ##### (36m)train

# %%
# train
cebra_multilayer_unitwise_model.fit(datas, unit_labels)
cebra_multilayer_unitwise_model.save(CEBRA_MODEL_MTLYR_UNIT_PATH)

# get each layer's embedding
multilayer_unitwise_embeddings = dict()
for i, (name, X) in enumerate(zip(names, datas)):
    multilayer_unitwise_embeddings[name] = cebra_multilayer_unitwise_model.transform(
        X, session_id=i
    )

# save
with open(CEBRA_EMBED_MTLYR_UNIT_PATH, "wb") as f:
    pickle.dump(multilayer_unitwise_embeddings, f)
# Out:
# pos: -0.6186 neg:  8.8884 total:  8.2698 temperature:  1.0000: 100%|██████████| 8000/8000 [36:30<00:00,  3.65it/s]

# %% [markdown]
# ##### plot
#
# **Null hypothesis**: EXC and INH units display similar responses across the cortical column.
# * Prediction: EXC and INH units' embeddings overlap consistently across layers, in the common latent space.
# * Results:
#     * EXC and INH units clustered into separate ensembles in the common latent space, consistently across layers.
#     * The radii of the EXC embeddings are larger (more spread) than those of INH embeddings (localized point).
#
# * TODO:
#     * is stimulus decodable from EXC units with the same accuracy across layer?
#     * is stimulus decodable from EXC units better than from INH units?

# %%
# plot
SIZE = 12

# init plot
# plt.set_cmap("hsv")  # circular cmap
cmap = matplotlib.colors.ListedColormap(["blue", "red"])
# matplotlib.pyplot.register_cmap(cmap=cmap, name="custom")
plt.set_cmap(cmap)  # circular cmap

fig = plt.figure(figsize=(15, 4))

# plot
ax = fig.add_subplot(1, 4, 1, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    multilayer_unitwise_embeddings["L2/3"][:, 0],
    multilayer_unitwise_embeddings["L2/3"][:, 1],
    multilayer_unitwise_embeddings["L2/3"][:, 2],
    c=unit_labels[0],
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot
ax = fig.add_subplot(1, 4, 2, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    multilayer_unitwise_embeddings["L4"][:, 0],
    multilayer_unitwise_embeddings["L4"][:, 1],
    multilayer_unitwise_embeddings["L4"][:, 2],
    c=unit_labels[1],
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot
ax = fig.add_subplot(1, 4, 3, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    multilayer_unitwise_embeddings["L5"][:, 0],
    multilayer_unitwise_embeddings["L5"][:, 1],
    multilayer_unitwise_embeddings["L5"][:, 2],
    c=unit_labels[2],
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot
ax = fig.add_subplot(1, 4, 4, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    multilayer_unitwise_embeddings["L6"][:, 0],
    multilayer_unitwise_embeddings["L6"][:, 1],
    multilayer_unitwise_embeddings["L6"][:, 2],
    c=unit_labels[3],
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,
)
plt.colorbar(scat)

# %% [markdown]
# # Exc units cluster by layer
#
# **Null hypothesis**: excitatory units display similar responses across the cortical column.
# * Prediction: excitatory units do not cluster by layer, but their embeddings overlap in the common latent space (independently of their layer).
# * Observation: EXC units clustered into ensembles segregated by layer, in the common latent space.
#
# * TODO:
#     * is stimulus decodable from EXC units with the same accuracy across layer?
#     * is stimulus decodable from EXC units better than from INH units?

# %%
# plot
SIZE = 12

fig = plt.figure(figsize=(15, 4))

# plot
ax = fig.add_subplot(1, 1, 1, projection="3d")
# ax.view_init(20, 45, 0)  # elevation, azimuth, roll
ax.view_init(-20, -45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    multilayer_unitwise_embeddings["L2/3"][np.where(unit_labels[0] == 0)[0], 0],
    multilayer_unitwise_embeddings["L2/3"][np.where(unit_labels[0] == 0)[0], 1],
    multilayer_unitwise_embeddings["L2/3"][np.where(unit_labels[0] == 0)[0], 2],
    edgecolors="w",
    color="r",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot
scat = ax.scatter(
    multilayer_unitwise_embeddings["L4"][np.where(unit_labels[1] == 0)[0], 0],
    multilayer_unitwise_embeddings["L4"][np.where(unit_labels[1] == 0)[0], 1],
    multilayer_unitwise_embeddings["L4"][np.where(unit_labels[1] == 0)[0], 2],
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot
scat = ax.scatter(
    multilayer_unitwise_embeddings["L5"][np.where(unit_labels[2] == 0)[0], 0],
    multilayer_unitwise_embeddings["L5"][np.where(unit_labels[2] == 0)[0], 1],
    multilayer_unitwise_embeddings["L5"][np.where(unit_labels[2] == 0)[0], 2],
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot
scat = ax.scatter(
    multilayer_unitwise_embeddings["L6"][np.where(unit_labels[3] == 0)[0], 0],
    multilayer_unitwise_embeddings["L6"][np.where(unit_labels[3] == 0)[0], 1],
    multilayer_unitwise_embeddings["L6"][np.where(unit_labels[3] == 0)[0], 2],
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,
)

# %% [markdown]
# # Exc units encode stimulus equally well
#
# **Null hypothesis**: Excitatory units from all layers encode the stimulus equally well.
#
# * time is the ordered index of a stimulus repetition (a trial) in CEBRA (trial sequence).
# * A stimulus response is the total spike count within a trial, so we discard within-trial time information.

# %% [markdown]
# #### (9m)Hybrid-mode embedding

# %%
np.random.seed(0)

MAX_ITER = 12000
SIZE = 1

# dataset *************************
os.makedirs(
    "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/stim-rep/models/cebra/models/",
    exist_ok=True,
)
CEBRA_L23_EXC = "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/stim-rep/models/cebra/models/l23_exc_trialwise_hybr_mode"
CEBRA_L4_EXC = "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/stim-rep/models/cebra/models/l4_exc_trialwise_hybr_mode"
CEBRA_L5_EXC = "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/stim-rep/models/cebra/models/l5_exc_trialwise_hybr_mode"
CEBRA_L6_EXC = "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/stim-rep/models/cebra/models/l6_exc_trialwise_hybr_mode"

# L23 exc responses
data_l23_exc = responses[(unit_layers == "2") | (unit_layers == "3"), :][
    np.where(unit_labels[0] == 0)[0], :
]
# L4 exc responses
data_l4_exc = responses[(unit_layers == "4"), :][np.where(unit_labels[1] == 0)[0], :]
# L5 exc responses
data_l5_exc = responses[(unit_layers == "5"), :][np.where(unit_labels[2] == 0)[0], :]
# L6 exc responses
data_l6_exc = responses[(unit_layers == "6"), :][np.where(unit_labels[3] == 0)[0], :]

model_cfg = {
    "model_architecture": "offset5-model",
    "batch_size": 1200,
    "learning_rate": 1e-4,
    "temperature": 1,
    "output_dimension": 3,
    "max_iterations": MAX_ITER,  # 8000,
    "distance": "cosine",
    "conditional": "time_delta",
    "device": "cuda_if_available",
    "verbose": True,
    "time_offsets": 10,
    "hybrid": True,
}

# cebra - behavior model
cebra_l23_model = CEBRA(**model_cfg)
cebra_l4_model = CEBRA(**model_cfg)
cebra_l5_model = CEBRA(**model_cfg)
cebra_l6_model = CEBRA(**model_cfg)

# (3m) train and save ******************************************
# train

cebra_l23_model.fit(data_l23_exc.T, np.array([stimulus_labels]).astype(float).T)
cebra_l23_model.save(CEBRA_L23_EXC + ".pt")

cebra_l4_model.fit(data_l4_exc.T, np.array([stimulus_labels]).astype(float).T)
cebra_l4_model.save(CEBRA_L4_EXC + ".pt")

cebra_l5_model.fit(data_l5_exc.T, np.array([stimulus_labels]).astype(float).T)
cebra_l5_model.save(CEBRA_L5_EXC + ".pt")

cebra_l6_model.fit(data_l6_exc.T, np.array([stimulus_labels]).astype(float).T)
cebra_l6_model.save(CEBRA_L6_EXC + ".pt")

# get each layer's embedding
cebra_l23_embed = dict()
cebra_l4_embed = dict()
cebra_l5_embed = dict()
cebra_l6_embed = dict()

cebra_l23_embed = cebra_l23_model.transform(data_l23_exc.T)
cebra_l4_embed = cebra_l4_model.transform(data_l4_exc.T)
cebra_l5_embed = cebra_l5_model.transform(data_l5_exc.T)
cebra_l6_embed = cebra_l6_model.transform(data_l6_exc.T)

# save
with open(CEBRA_L23_EXC + ".pkl", "wb") as f:
    pickle.dump(cebra_l23_embed, f)
with open(CEBRA_L4_EXC + ".pkl", "wb") as f:
    pickle.dump(cebra_l4_embed, f)
with open(CEBRA_L5_EXC + ".pkl", "wb") as f:
    pickle.dump(cebra_l5_embed, f)
with open(CEBRA_L6_EXC + ".pkl", "wb") as f:
    pickle.dump(cebra_l6_embed, f)


# plot ***********************************************

# init plot
plt.set_cmap("hsv")  # circular cmap
fig = plt.figure(figsize=(15, 4))

# plot
ax = fig.add_subplot(1, 4, 1, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    cebra_l23_embed[:, 0],
    cebra_l23_embed[:, 1],
    cebra_l23_embed[:, 2],
    c=stimulus_labels,
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot
ax = fig.add_subplot(1, 4, 2, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    cebra_l4_embed[:, 0],
    cebra_l4_embed[:, 1],
    cebra_l4_embed[:, 2],
    c=stimulus_labels,
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot ******************************************
ax = fig.add_subplot(1, 4, 3, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    cebra_l5_embed[:, 0],
    cebra_l5_embed[:, 1],
    cebra_l5_embed[:, 2],
    c=stimulus_labels,
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot
ax = fig.add_subplot(1, 4, 4, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    cebra_l6_embed[:, 0],
    cebra_l6_embed[:, 1],
    cebra_l6_embed[:, 2],
    c=stimulus_labels,
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,
)
# Out:
# behavior_pos: -0.9981 behavior_neg:  7.2523 behavior_total:  6.2542 time_pos: -0.9978 time_neg:  7.2523 time_total:  6.2545: 100%|██████████| 12000/12000 [02:44<00:00, 72.89it/s]
# behavior_pos: -0.9976 behavior_neg:  7.2534 behavior_total:  6.2558 time_pos: -0.9967 time_neg:  7.2534 time_total:  6.2567: 100%|██████████| 12000/12000 [02:17<00:00, 87.01it/s]
# behavior_pos: -0.9983 behavior_neg:  7.2520 behavior_total:  6.2537 time_pos: -0.9980 time_neg:  7.2520 time_total:  6.2540: 100%|██████████| 12000/12000 [02:22<00:00, 84.11it/s]
# behavior_pos: -0.9984 behavior_neg:  7.2532 behavior_total:  6.2548 time_pos: -0.9984 time_neg:  7.2532 time_total:  6.2548: 100%|██████████| 12000/12000 [02:48<00:00, 71.29it/s]

# %% [markdown]
# #### (5m) Behavior-mode embedding

# %%
MAX_ITER = 12000
SIZE = 1

# dataset *************************
os.makedirs(
    "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/stim-rep/models/cebra/models/",
    exist_ok=True,
)
CEBRA_L23_EXC = "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/stim-rep/models/cebra/models/l23_exc_trialwise_beh_mode"
CEBRA_L4_EXC = "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/stim-rep/models/cebra/models/l4_exc_trialwise_beh_mode"
CEBRA_L5_EXC = "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/stim-rep/models/cebra/models/l5_exc_trialwise_beh_mode"
CEBRA_L6_EXC = "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/stim-rep/models/cebra/models/l6_exc_trialwise_beh_mode"

# L23 exc responses
data_l23_exc = responses[(unit_layers == "2") | (unit_layers == "3"), :][
    np.where(unit_labels[0] == 0)[0], :
]
# L4 exc responses
data_l4_exc = responses[(unit_layers == "4"), :][np.where(unit_labels[1] == 0)[0], :]
# L5 exc responses
data_l5_exc = responses[(unit_layers == "5"), :][np.where(unit_labels[2] == 0)[0], :]
# L6 exc responses
data_l6_exc = responses[(unit_layers == "6"), :][np.where(unit_labels[3] == 0)[0], :]

model_cfg = {
    "model_architecture": "offset5-model",
    "batch_size": 1200,
    "learning_rate": 1e-4,
    "temperature": 1,
    "output_dimension": 3,
    "max_iterations": MAX_ITER,  # 8000,
    "distance": "cosine",
    "conditional": "time_delta",
    "device": "cuda_if_available",
    "verbose": True,
    "time_offsets": 10,
}

# cebra - behavior model
cebra_l23_model = CEBRA(**model_cfg)
cebra_l4_model = CEBRA(**model_cfg)
cebra_l5_model = CEBRA(**model_cfg)
cebra_l6_model = CEBRA(**model_cfg)

# (3m) train and save ******************************************
# train
np.random.seed(0)

cebra_l23_model.fit(data_l23_exc.T, np.array([stimulus_labels]).astype(float).T)
cebra_l23_model.save(CEBRA_L23_EXC + ".pt")

cebra_l4_model.fit(data_l4_exc.T, np.array([stimulus_labels]).astype(float).T)
cebra_l4_model.save(CEBRA_L4_EXC + ".pt")

cebra_l5_model.fit(data_l5_exc.T, np.array([stimulus_labels]).astype(float).T)
cebra_l5_model.save(CEBRA_L5_EXC + ".pt")

cebra_l6_model.fit(data_l6_exc.T, np.array([stimulus_labels]).astype(float).T)
cebra_l6_model.save(CEBRA_L6_EXC + ".pt")

# get each layer's embedding
cebra_l23_embed = dict()
cebra_l4_embed = dict()
cebra_l5_embed = dict()
cebra_l6_embed = dict()

cebra_l23_embed = cebra_l23_model.transform(data_l23_exc.T)
cebra_l4_embed = cebra_l4_model.transform(data_l4_exc.T)
cebra_l5_embed = cebra_l5_model.transform(data_l5_exc.T)
cebra_l6_embed = cebra_l6_model.transform(data_l6_exc.T)

# save
with open(CEBRA_L23_EXC + ".pkl", "wb") as f:
    pickle.dump(cebra_l23_embed, f)
with open(CEBRA_L4_EXC + ".pkl", "wb") as f:
    pickle.dump(cebra_l4_embed, f)
with open(CEBRA_L5_EXC + ".pkl", "wb") as f:
    pickle.dump(cebra_l5_embed, f)
with open(CEBRA_L6_EXC + ".pkl", "wb") as f:
    pickle.dump(cebra_l6_embed, f)


# plot ***********************************************

# init plot
plt.set_cmap("hsv")  # circular cmap
fig = plt.figure(figsize=(15, 4))

# plot
ax = fig.add_subplot(1, 4, 1, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    cebra_l23_embed[:, 0],
    cebra_l23_embed[:, 1],
    cebra_l23_embed[:, 2],
    c=stimulus_labels,
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot
ax = fig.add_subplot(1, 4, 2, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    cebra_l4_embed[:, 0],
    cebra_l4_embed[:, 1],
    cebra_l4_embed[:, 2],
    c=stimulus_labels,
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot ******************************************
ax = fig.add_subplot(1, 4, 3, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    cebra_l5_embed[:, 0],
    cebra_l5_embed[:, 1],
    cebra_l5_embed[:, 2],
    c=stimulus_labels,
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,  # memory efficiency
)

# plot
ax = fig.add_subplot(1, 4, 4, projection="3d")
ax.view_init(20, 45, 0)  # elevation, azimuth, roll
scat = ax.scatter(
    cebra_l6_embed[:, 0],
    cebra_l6_embed[:, 1],
    cebra_l6_embed[:, 2],
    c=stimulus_labels,
    edgecolors="w",
    linewidths=0.2,
    s=SIZE,
    rasterized=True,
)
# Out:
# pos: -0.9975 neg:  7.2522 total:  6.2548 temperature:  1.0000: 100%|██████████| 12000/12000 [01:28<00:00, 136.32it/s]
# pos: -0.9973 neg:  7.2540 total:  6.2567 temperature:  1.0000: 100%|██████████| 12000/12000 [01:22<00:00, 144.93it/s]
# pos: -0.9978 neg:  7.2520 total:  6.2543 temperature:  1.0000: 100%|██████████| 12000/12000 [01:26<00:00, 139.53it/s]
# pos: -0.9985 neg:  7.2518 total:  6.2533 temperature:  1.0000: 100%|██████████| 12000/12000 [01:36<00:00, 124.59it/s]

# %% [markdown]
# ### Decoding
#
# * We cannot cross-validate from the hybrid mode without having several simulations, which would allow to conserve time information for prediction. Currently, we cannot use 75% of trials, of 0 degrees for example, to predict the remaining 0 deg test trials as response change over trials will add noise.
# * We use CEBRA-behavior to decode, assuming response changes are negligible over trial repetitions of the same stimulus.

# %%
import sklearn


# custom functions
def split(response, labels, test_ratio):

    split_idx = int(len(response) * (1 - test_ratio))
    neural_train = response[:split_idx]
    neural_test = response[split_idx:]
    label_train = labels[:split_idx]
    label_test = labels[split_idx:]

    return (
        neural_train.numpy(),
        neural_test.numpy(),
        label_train.numpy(),
        label_test.numpy(),
    )


def decode(embed_train, embed_test, label_train, label_test):
    """decoding using a k-Nearest Neighbor clustering technique
    We use the fixed number of neighbors 36
    """
    # predict
    decoder = cebra.KNNDecoder(n_neighbors=36, metric="cosine")
    decoder.fit(embed_train, label_train[:, 1])
    prediction = decoder.predict(embed_test)

    # calculate error
    test_err = np.median(abs(prediction - label_test))
    test_r2 = sklearn.metrics.r2_score(label_test, prediction)
    return test_err, test_r2

# %%
int(len(stimulus_labels) * (1 - 0.75))
# take first 75% of stimulus trials to predict the remaining 25% for each stimulus
# Out:
# 4500

# %%
test_err, test_r2 = decode(
    cebra_l23_embed_train, cebra_l23_embed_test, label_train, label_test
)
